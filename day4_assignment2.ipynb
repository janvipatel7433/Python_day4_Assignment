# %%
str1 = 'python'
print(str1.islower())
# Out:
# True

# %%
str2 = "Python"
print(str1.isupper())
# Out:
# False

# %%
str3 = "python3"
print(str3.islower())
# Out:
# True

# %%
str4 = "3python"
print(str4.islower())
# Out:
# True

# %%
str5 = "PYTHON3"
print(str5.isupper())
# Out:
# True

# %%
str6 = "3PYTHON"
print(str6.isupper())
# Out:
# True

# %%
str7 = "pyth7on"
print(str7.islower())
# Out:
# True

# %%
str8 = "PYTH7ON"
print(str8.isupper())
# Out:
# True
